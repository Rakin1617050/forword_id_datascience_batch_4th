# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
df[::-1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 767            1       93             70             31        0  30.4
# 766            1      126             60              0        0  30.1
# 765            5      121             72             23      112  26.2
# 764            2      122             70             27        0  36.8
# 763           10      101             76             48      180  32.9
# ..           ...      ...            ...            ...      ...   ...
# 4              0      137             40             35      168  43.1
# 3              1       89             66             23       94  28.1
# 2              8      183             64              0        0  23.3
# 1              1       85             66             29        0  26.6
# 0              6      148             72             35        0  33.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 767                     0.315   23        0
# ...

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df["Glucose"][df["Glucose"] == 0].count()
# Out:
# 5

# %%
df["BloodPressure"][df["BloodPressure"] == 0].count()
# Out:
# 35

# %%
df["SkinThickness"][df["SkinThickness"] == 0].count()
# Out:
# 227

# %%
df["Insulin"][df["Insulin"] == 0].count()
# Out:
# 374

# %%
df["BMI"][df["BMI"] == 0].count()
# Out:
# 11

# %%
df_copy = df.copy()

# %%
df_copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] = df_copy[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].replace(0, np.NAN)

# %%
df_copy["Insulin"][df["Insulin"] == 0].count()
# Out:
# 0

# %%
df_copy.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0      NaN  33.6
# 1            1     85.0           66.0           29.0      NaN  26.6
# 2            8    183.0           64.0            NaN      NaN  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df_copy.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
h = df_copy.hist(figsize=(20, 20))

# %%
df_copy["Glucose"].fillna(df_copy["Glucose"].mean(), inplace = True)

# %%
df_copy.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df_copy["BloodPressure"].fillna(df_copy["BloodPressure"].mean(), inplace = True)

# %%
df_copy["SkinThickness"].fillna(df_copy["SkinThickness"].median(), inplace = True)

# %%
df_copy["Insulin"].fillna(df_copy["Insulin"].median(), inplace = True)

# %%
df_copy["BMI"].fillna(df_copy["BMI"].median(), inplace = True)

# %%
h = df_copy.hist(figsize=(20, 20))

# %%
# check missing values using visualize
import missingno

# %%
df_null = df.copy()

# %%
df_null[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] = df_null[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].replace(0, np.NAN)

# %%
p = missingno.bar(df_null)

# %%
p = missingno.bar(df_copy)

# %%
p = df_copy["Outcome"].value_counts().plot(kind="bar")

# %%
df_copy.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.127911       0.208522       0.081770
# Glucose                      0.127911  1.000000       0.218367       0.192686
# BloodPressure                0.208522  0.218367       1.000000       0.191853
# SkinThickness                0.081770  0.192686       0.191853       1.000000
# Insulin                      0.025047  0.419064       0.045087       0.155610
# BMI                          0.021559  0.231128       0.281199       0.543205
# DiabetesPedigreeFunction    -0.033523  0.137060      -0.002763       0.102188
# Age                          0.544341  0.266534       0.324595       0.126107
# Outcome                      0.221898  0.492928       0.166074       0.214873
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies               0.025047  0.021559                 -0.033523
# ...

# %%
from pandas.plotting import scatter_matrix

# %%
p = scatter_matrix(df_copy, figsize=(20, 20))

# %%
plt.figure(figsize=(20, 10))
p = sns.heatmap(df_copy.corr(), annot=True, cmap="RdYlGn")

# %%
df_ss = df_copy.drop("Outcome", axis=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc_X = StandardScaler()

# %%
df_ss.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
X = pd.DataFrame(sc_X.fit_transform(df_ss), columns=['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age'])
X.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.865108      -0.033518       0.670643 -0.181541  0.166619
# 1    -0.844885 -1.206162      -0.529859      -0.012301 -0.181541 -0.852200
# 2     1.233880  2.015813      -0.695306      -0.012301 -0.181541 -1.332500
# 3    -0.844885 -1.074652      -0.529859      -0.695245 -0.540642 -0.633881
# 4    -1.141852  0.503458      -2.680669       0.670643  0.316566  1.549303
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  1.425995
# 1                 -0.365061 -0.190672
# 2                  0.604397 -0.105584
# 3                 -0.920763 -1.041549
# 4                  5.484909 -0.020496
