# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.DataFrame(np.random.randn(1000), index = pd.date_range('2020-01-01', periods=1000), columns=['value'])

# %%
df.head()
# Out:
#                value
# 2020-01-01  0.968320
# 2020-01-02  0.133922
# 2020-01-03  1.991078
# 2020-01-04  1.031218
# 2020-01-05  1.866956

# %%
ts = pd.Series(np.random.randn(10), index = pd.date_range('2020-01-01', periods=10))

# %%
ts.head()
# Out:
# 2020-01-01   -0.857188
# 2020-01-02   -1.652189
# 2020-01-03    0.332179
# 2020-01-04    0.452072
# 2020-01-05   -0.195655
# Freq: D, dtype: float64

# %%
df['value'] = df['value'].cumsum()
df.head()
# Out:
#                value
# 2020-01-01  0.968320
# 2020-01-02  1.102242
# 2020-01-03  3.093320
# 2020-01-04  4.124538
# 2020-01-05  5.991494

# %%
ts.plot(figsize=(5, 5))
# Out:
# <AxesSubplot:>

# %%
plt.plot(ts)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
plt.plot(df)

# %%
iris_data = sns.load_dataset('iris')
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax = iris_data.plot(figsize=(15, 6), title="IRIS Data set")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
# Out:
# Text(0, 0.5, 'Y axis')

# %%
ts.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_iris = iris_data.drop(['species'], axis=1)

# %%
df_iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df_iris.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df_iris.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_iris.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_titanic = sns.load_dataset('titanic')

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_titanic['pclass'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
t_pclass = df_titanic['pclass'].head(15)

# %%
t_pclass
# Out:
# 0     3
# 1     1
# 2     3
# 3     1
# 4     3
# 5     3
# 6     1
# 7     3
# 8     3
# 9     2
# 10    3
# 11    1
# 12    3
# 13    3
# 14    3
# Name: pclass, dtype: int64

# %%
t_pclass.plot.bar()
# Out:
# <AxesSubplot:>

# %%
# histogram
iris_data.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris_data.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris_data.plot(kind='hist', stacked=False, bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris_data.plot(kind='hist', stacked=False, bins=50, orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris_data['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris_data['sepal_width'].diff().plot(kind='hist', stacked=True, bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_iris.diff()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             NaN          NaN           NaN          NaN
# 1            -0.2         -0.5           0.0          0.0
# 2            -0.2          0.2          -0.1          0.0
# 3            -0.1         -0.1           0.2          0.0
# 4             0.4          0.5          -0.1          0.0
# ..            ...          ...           ...          ...
# 145           0.0         -0.3          -0.5         -0.2
# 146          -0.4         -0.5          -0.2         -0.4
# 147           0.2          0.5           0.2          0.1
# 148          -0.3          0.4           0.2          0.3
# 149          -0.3         -0.4          -0.3         -0.5
#
# [150 rows x 4 columns]

# %%
df_iris.diff().hist(color='blue', alpha=0.1, figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df_iris.plot.scatter(x='sepal_length', y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
pd.plotting.scatter_matrix(df_iris, figsize=(12, 6), color='b')
plt.show()

# %%
df_iris.plot.scatter(x='petal_width', y='petal_length')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>

# %%
df_iris.plot.scatter(x='petal_width', y='petal_length', c='sepal_width')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>

# %%
df_iris.plot.scatter(x='petal_width', y='petal_length', color='y')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>

# %%
df_iris.plot.scatter(x='petal_width', y='petal_length', color='y', s=200)
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>

# %%
df_iris.iloc[0].plot.pie(figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d = df_iris.head(10)
d.plot.pie(subplots=True, figsize=(10, 10))
# Out:
# array([<AxesSubplot:ylabel='sepal_length'>,
#        <AxesSubplot:ylabel='sepal_width'>,
#        <AxesSubplot:ylabel='petal_length'>,
#        <AxesSubplot:ylabel='petal_width'>], dtype=object)

# %%
d = df_iris.head(5).T
d.plot.pie(subplots=True, figsize=(20, 20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>, <AxesSubplot:ylabel='3'>,
#        <AxesSubplot:ylabel='4'>], dtype=object)

# %%
d.plot.pie(subplots=True, figsize=(20, 20), fontsize=10, autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>, <AxesSubplot:ylabel='3'>,
#        <AxesSubplot:ylabel='4'>], dtype=object)

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df_iris, 'sepal_width')
# Out:
# <AxesSubplot:>

# %%
df_tip = sns.load_dataset('tips')
df_tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill', y='tip', data=df_tip)

# %%
sns.relplot(x='total_bill', y='tip', data=df_tip, hue='sex', style='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=df_tip, hue='sex', style='size')

# %%
sns.relplot(x='total_bill', y='tip', data=df_tip, hue='size', style='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=df_tip, hue='sex', size='size')

# %%
sns.relplot(x='total_bill', y='tip', data=df_tip, hue='sex', style='smoker', col='time')

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker',  data=df_tip, col='size', col_wrap=3, height=3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\anaconda_folder\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1471             try:
# -> 1472                 order = vector.cat.categories
#    1473             except (TypeError, AttributeError):
#
# D:\anaconda_folder\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#
# AttributeError: 'DataFrame' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# D:\anaconda_folder\lib\site-packages\seaborn\_core.py in categorical_order(vector, order)
#    1475                 try:
# -> 1476                     order = vector.unique()
# ...

# %%
sns.scatterplot(x='total_bill', y='tip', data=df_tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.catplot(x='day', y='total_bill', data=df_tip)

# %%
sns.catplot(y='day', x='total_bill', data=df_tip)

# %%
sns.catplot(y='day', x='total_bill', data=df_tip, jitter=False)

# %%
sns.catplot(x='day', y='total_bill', data=df_tip, kind='swarm', hue='size')

# %%
sns.catplot(x='day', y='tip', data=df_tip, kind='box', hue='sex')

# %% [markdown]
# # visualizartion distribution of data
# * distplot

# %%
x = np.random.randn(100)

# %%
sns.distplot(x, kde=True, hist=True, bins=30)
# Out:
# D:\anaconda_folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
x = df_tip['total_bill']
y = df_tip['tip']

# %%
sns.jointplot(x=x,y=y)

# %%
sns.jointplot(x=x,y=y, kind='hex')

# %%
sns.jointplot(x=x,y=y, kind='kde')

# %%
sns.pairplot(df_tip)

# %%
sns.lmplot(x='total_bill', y='tip', data=df_tip)
